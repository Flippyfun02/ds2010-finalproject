# %%
import pandas as pd

data = pd.read_csv("FraudShield_Banking_Data.csv")

data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Transaction_ID                         49997 non-null  float64
#  1   Customer_ID                            49990 non-null  float64
#  2   Transaction_Amount (in Million)        49991 non-null  float64
#  3   Transaction_Time                       49991 non-null  str
#  4   Transaction_Date                       49997 non-null  str
#  5   Transaction_Type                       49996 non-null  str
#  6   Merchant_ID                            49993 non-null  float64
#  7   Merchant_Category                      49991 non-null  str
#  8   Transaction_Location                   49994 non-null  str
#  9   Customer_Home_Location                 49996 non-null  str
#  10  Distance_From_Home                     49998 non-null  float64
# ...

# %%
data.head(100)
# Out:
#     Transaction_ID  Customer_ID  Transaction_Amount (in Million)  \
# 0         431438.0      24239.0                              6.0
# 1         902451.0      77250.0                              9.0
# 2         223410.0      34294.0                              3.0
# 3         145626.0      92041.0                              1.0
# 4         414637.0      71578.0                              1.0
# ..             ...          ...                              ...
# 95        603311.0      74137.0                              2.0
# 96        478545.0      34516.0                              4.0
# 97        896253.0      57088.0                              3.0
# 98        229720.0      40378.0                              9.0
# 99        975288.0      96726.0                              1.0
#
#    Transaction_Time Transaction_Date Transaction_Type  Merchant_ID  \
# 0             10:54       2025-03-08              POS      97028.0
# ...

# %%
data.describe()
# Out:
#        Transaction_ID   Customer_ID  Transaction_Amount (in Million)  \
# count    49997.000000  49990.000000                     49991.000000
# mean    550400.968898  54869.720744                         4.999880
# std     259677.602349  26052.824933                         2.582025
# min     100043.000000  10005.000000                         1.000000
# 25%     324445.000000  32259.250000                         3.000000
# 50%     552115.000000  54720.500000                         5.000000
# 75%     775942.000000  77542.000000                         7.000000
# max     999992.000000  99996.000000                         9.000000
#
#         Merchant_ID  Distance_From_Home      Device_ID  \
# count  49993.000000        49998.000000   49991.000000
# mean   54951.375913          300.098564  552563.600088
# std    25983.342481          172.848263  260186.451027
# min    10001.000000            1.000000  100053.000000
# 25%    32545.000000          150.000000  327643.500000
# ...

# %%
def report(df):
    return pd.DataFrame({
            "dtype": df.dtypes,
            "missing_count": df.isna().sum(),
            "missing_pct": df.isna().mean() * 100,
            "unique_values": df.nunique(),
        }).sort_values(by="missing_pct", ascending=False)

before_report = report(data)
before_report
# Out:
#                                          dtype  missing_count  missing_pct  \
# Failed_Transaction_Count               float64             11        0.022
# Customer_ID                            float64             10        0.020
# Transaction_Amount (in Million)        float64              9        0.018
# Transaction_Time                           str              9        0.018
# Merchant_Category                          str              9        0.018
# Device_ID                              float64              9        0.018
# Avg_Transaction_Amount (in Million)    float64              9        0.018
# Account_Balance (in Million)           float64              9        0.018
# Daily_Transaction_Count                float64              9        0.018
# Merchant_ID                            float64              7        0.014
# IP_Address                                 str              6        0.012
# ...

# %%
data_new = data.drop(columns=['Customer_ID', 'Merchant_ID', 'Device_ID', ])
data_new.dropna(inplace=True)
data_new.describe()
# Out:
#        Transaction_ID  Transaction_Amount (in Million)  Distance_From_Home  \
# count    49876.000000                     49876.000000        49876.000000
# mean    550390.651355                         4.999880          300.143135
# std     259736.531218                         2.581608          172.851676
# min     100043.000000                         1.000000            1.000000
# 25%     324307.750000                         3.000000          150.000000
# 50%     551948.500000                         5.000000          301.000000
# 75%     776076.750000                         7.000000          449.000000
# max     999992.000000                         9.000000          599.000000
#
#        Account_Balance (in Million)  Daily_Transaction_Count  \
# count                  49876.000000             49876.000000
# mean                      20.992902                 3.999439
# std                       10.684314                 2.002595
# ...

# %%
after_report = report(data_new)
after_report
# Out:
#                                          dtype  missing_count  missing_pct  \
# Transaction_ID                         float64              0          0.0
# Transaction_Amount (in Million)        float64              0          0.0
# Previous_Fraud_Count                   float64              0          0.0
# Unusual_Time_Transaction                   str              0          0.0
# Failed_Transaction_Count               float64              0          0.0
# Is_New_Merchant                            str              0          0.0
# Is_International_Transaction               str              0          0.0
# Max_Transaction_Last_24h (in Million)  float64              0          0.0
# Avg_Transaction_Amount (in Million)    float64              0          0.0
# Weekly_Transaction_Count               float64              0          0.0
# Daily_Transaction_Count                float64              0          0.0
# ...

# %%
data_new['Is_New_Merchant'] = data_new['Is_New_Merchant'].map({'Yes': 1, 'No': 0}, na_action='ignore')
data_new['Is_International_Transaction'] = data_new['Is_International_Transaction'].map({'Yes': 1, 'No': 0},na_action='ignore')

print(data_new['Is_International_Transaction'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 49995   NaN
# 49996   NaN
# 49997   NaN
# 49998   NaN
# 49999   NaN
# Name: Is_International_Transaction, Length: 49876, dtype: float64
