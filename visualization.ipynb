# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("clean_data.csv")

data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49876 entries, 0 to 49875
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             49876 non-null  int64
#  1   Transaction_ID                         49876 non-null  float64
#  2   Transaction_Amount (in Million)        49876 non-null  float64
#  3   Transaction_Time                       49876 non-null  str
#  4   Transaction_Date                       49876 non-null  str
#  5   Transaction_Type                       49876 non-null  str
#  6   Merchant_Category                      49876 non-null  str
#  7   Transaction_Location                   49876 non-null  str
#  8   Customer_Home_Location                 49876 non-null  str
#  9   Distance_From_Home                     49876 non-null  float64
#  10  IP_Address                             49876 non-null  str
# ...
